# %%
## TAREA: Método Seaborn
    # - Es una biblioteca de visualización de datos en Python construida sobre Matplotlib que proporciona una interfaz para crear gráficos estadísticos. 
    # - Está diseñada para trabajar con estructuras de datos de Pandas, lo que a su vez facilita la generación de visualizaciones directamente desde dataframes y arrays.
# Entre los tipos de gráficos más comunes que facilita están:
    # - Scatter plots
    # - Box plots
    # - Heatmaps
    # - Violin plots
    # - Regresiones lineales

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = r"C:\Users\holai\OneDrive\Escritorio\Semestre 5\Modelos Computacionales I\Neurociencias-2025-1\datasets\cancer_regression\cancer_reg.csv"
df_cancer = pd.read_csv(csv_path, sep=",")

# %%
# Histograma Método 1: Pandas
df_cancer.hist(column='medianage', bins=1000)
# El título se pone automático 
plt.xlabel('Edad Media')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Histograma Método 2: Matplotlib
plt.hist(df_cancer['medianage'], bins=1000)
plt.title('Distribución de la Edad Media')
plt.xlabel('Edad Media')
plt.ylabel('Frecuencia')
plt.show()
# Aquí no hay ningún label automático

# %%
# Histograma Método 3: Seaborn
sns.histplot(df_cancer['medianage'], bins=1000, stat='frequency') 
# stat = frequency se encarga que en el eje Y se muestren las frecuencias absolutas, es decir, el número de elementos que caen en cada "bin" del histograma
plt.title('Distribución de la Edad Media')
plt.show()
# Los labels de los ejes se ponen en automático con seaborn

# %%
# Todos los labels se agregan con matplotlib (plt.) porque pandas y seaborn son bibliotecas construidas sobre eso
